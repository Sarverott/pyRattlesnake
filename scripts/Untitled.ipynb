# %%
import templater
templater.THIS
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import templater
#       2 templater.THIS
#
# File ~/__WORKSHOP/forge/inceptorium-apokryf/pyRattlesnake/scripts/templater/__init__.py:15
#       8     return {
#       9         "filepath": str((pathlib.Path(file_const) ).resolve()),
#      10         "dirpath": str((pathlib.Path(file_const) / "..").resolve())
#      11     }
#      13 THIS = generate_this(__file__)
# ---> 15 from templates import Taskfile
#
# ModuleNotFoundError: No module named 'templates'

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 templater
#
# NameError: name 'templater' is not defined
